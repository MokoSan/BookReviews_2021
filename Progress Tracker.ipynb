# %%
import matplotlib.pyplot as plt
import calendar

# %%
# %matplotlib inline

# %%
months = [calendar.month_name[i] for i in range(1, 13)]
data   = [4, 4, 6, 5, 2, 1, 4, 3, 4, 4, 4, 4]

plt.bar(months, data)
plt.title(f'Books Read So Far: {sum(data)}; Goal: 45; Remaining: {45 - sum(data)}')
plt.xticks(rotation='vertical')
plt.xlabel('Month')
plt.ylabel('# of Books')
plt.show()
